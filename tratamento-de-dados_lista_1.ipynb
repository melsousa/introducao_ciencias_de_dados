# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib as plt

# %%
df = pd.read_csv('../../datasets/telegram/fakeTelegram.BR_2022.csv')
df.head()
# Out:
#           date_message               id_member_anonymous  \
# 0  2022-10-05 06:25:04  1078cc958f0febe28f4d03207660715f
# 1  2022-10-05 06:25:08                               NaN
# 2  2022-10-05 06:26:28  92a2d8fd7144074f659d1d29dc3751da
# 3  2022-10-05 06:27:28  d60aa38f62b4977426b70944af4aff72
# 4  2022-10-05 06:27:44  cd6979b0b5265f08468fa1689b6300ce
#
#                  id_group_anonymous                                 media  \
# 0  12283e08a2eb5789201e105b34489ee7                                   NaN
# 1  12283e08a2eb5789201e105b34489ee7                                   NaN
# 2  9f2d7394334eb224c061c9740b5748fc                                   NaN
# 3  c8f2de56550ed0bf85249608b7ead93d  94dca4cda503100ebfda7ce2bcc060eb.jpg
# 4  e56ec342fc599ebb4ed89655eb6f03aa  5ad5c8bbe9da93a37fecf3e5aa5b0637.jpg
#
#   media_type media_url  has_media  has_media_url  trava_zap  \
# 0        NaN       NaN      False          False      False
# 1        NaN       NaN      False          False      False
# 2        NaN       NaN      False          False      False
# 3  image/jpg       NaN       True          False      False
# 4  image/jpg       NaN       True          False      False
#
#                               text_content_anonymous  dataset_info_id  \
# 0  Então é Fato Renato o áudio que eu ouvi no wha...                5
# 1  Saiu no YouTube do presidente a 8 horas atrás,...                5
# 2  É isso, nossa parte já foi quase toda feita. N...                5
# 3           GENTE ACHEI ELES EM UMA SEITA MAÇONÁRICA                5
# 4                                                NaN                5
#
#                   date_system  score_sentiment  score_misinformation  \
# 0  2022-10-05 06:25:28.863641           0.0000                   NaN
# 1  2022-10-05 06:25:28.926311           0.0644                   NaN
# 2  2022-10-05 06:26:29.361949          -0.3551              0.157242
# 3  2022-10-05 06:27:29.935624           0.0000                   NaN
# 4  2022-10-05 06:28:29.316325              NaN                   NaN
#
#    id_message message_type messenger media_name  \
# 0       16385        Texto  telegram        NaN
# 1       16386        Texto  telegram        NaN
# 2       16366        Texto  telegram        NaN
# 3       19281       Imagem  telegram        NaN
# 4      507185       Imagem  telegram        NaN
#
#                           media_md5
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3  94dca4cda503100ebfda7ce2bcc060eb
# 4  5ad5c8bbe9da93a37fecf3e5aa5b0637

# %%
# Linhas e colunas
df.shape
# Out:
# (557586, 19)

# %%
df.isnull()
# Out:
#         date_message  id_member_anonymous  id_group_anonymous  media  \
# 0              False                False               False   True
# 1              False                 True               False   True
# 2              False                False               False   True
# 3              False                False               False  False
# 4              False                False               False  False
# ...              ...                  ...                 ...    ...
# 557581         False                False               False  False
# 557582         False                 True               False  False
# 557583         False                 True               False  False
# 557584         False                 True               False  False
# 557585         False                 True               False  False
#
#         media_type  media_url  has_media  has_media_url  trava_zap  \
# 0             True       True      False          False      False
# 1             True       True      False          False      False
# 2             True       True      False          False      False
# 3            False       True      False          False      False
# 4            False       True      False          False      False
# ...            ...        ...        ...            ...        ...
# 557581       False      False      False          False      False
# 557582       False      False      False          False      False
# 557583       False      False      False          False      False
# 557584       False      False      False          False      False
# 557585       False      False      False          False      False
#
#         text_content_anonymous  dataset_info_id  date_system  score_sentiment  \
# 0                        False            False        False            False
# 1                        False            False        False            False
# 2                        False            False        False            False
# 3                        False            False        False            False
# 4                         True            False        False             True
# ...                        ...              ...          ...              ...
# 557581                   False            False        False            False
# 557582                   False            False        False            False
# 557583                   False            False        False            False
# 557584                   False            False        False            False
# 557585                   False            False        False            False
#
#         score_misinformation  id_message  message_type  messenger  media_name  \
# 0                       True       False         False      False        True
# 1                       True       False         False      False        True
# 2                      False       False         False      False        True
# 3                       True       False         False      False        True
# 4                       True       False         False      False        True
# ...                      ...         ...           ...        ...         ...
# 557581                  True       False         False      False        True
# 557582                  True       False         False      False        True
# 557583                  True       False         False      False        True
# 557584                  True       False         False      False        True
# 557585                  True       False         False      False        True
#
#         media_md5
# 0            True
# 1            True
# 2            True
# 3           False
# 4           False
# ...           ...
# 557581      False
# 557582      False
# 557583      False
# 557584      False
# 557585      False
#
# [557586 rows x 19 columns]

# %%
# Somando quantas celulas estão faltando 
linhas_nulas = df.isnull().sum(axis=1)
print(sum(linhas_nulas))
# Out:
# 2544186

# %%
# Contando quantos valores faltantes possuem cada coluna
valores_nulos = df.isnull().sum()
print(valores_nulos)
# Out:
# date_message                   0
# id_member_anonymous       323341
# id_group_anonymous             0
# media                     224981
# media_type                224981
# media_url                 400141
# has_media                      0
# has_media_url                  0
# trava_zap                      0
# text_content_anonymous    113385
# dataset_info_id                0
# date_system                    0
# score_sentiment           113429
# score_misinformation      390348
# id_message                     0
# message_type                   0
# messenger                      0
# media_name                528599
# media_md5                 224981
# dtype: int64

# %%
# Indentificando linhas repetidas
duplicadas = df.duplicated()
linhas_duplicadas = df[duplicadas]

print(linhas_duplicadas)
# Out:
# Empty DataFrame
# Columns: [date_message, id_member_anonymous, id_group_anonymous, media, media_type, media_url, has_media, has_media_url, trava_zap, text_content_anonymous, dataset_info_id, date_system, score_sentiment, score_misinformation, id_message, message_type, messenger, media_name, media_md5]
# Index: []

# %%
df.dtypes
# Out:
# date_message               object
# id_member_anonymous        object
# id_group_anonymous         object
# media                      object
# media_type                 object
# media_url                  object
# has_media                    bool
# has_media_url                bool
# trava_zap                    bool
# text_content_anonymous     object
# dataset_info_id             int64
# date_system                object
# score_sentiment           float64
# score_misinformation      float64
# id_message                  int64
# message_type               object
# messenger                  object
# media_name                 object
# media_md5                  object
# dtype: object

# %%
# f
# Modificando tipo de dados
df['date_message'] = pd.to_datetime(df['date_message'])
df['date_system'] = pd.to_datetime(df['date_system'])

df.dtypes
# Out:
# date_message              datetime64[ns]
# id_member_anonymous               object
# id_group_anonymous                object
# media                             object
# media_type                        object
# media_url                         object
# has_media                           bool
# has_media_url                       bool
# trava_zap                           bool
# text_content_anonymous            object
# dataset_info_id                    int64
# date_system               datetime64[ns]
# score_sentiment                  float64
# score_misinformation             float64
# id_message                         int64
# message_type                      object
# messenger                         object
# media_name                        object
# media_md5                         object
# dtype: object

# %%
df.head()
# Out:
#          date_message               id_member_anonymous  \
# 0 2022-10-05 06:25:04  1078cc958f0febe28f4d03207660715f
# 1 2022-10-05 06:25:08                               NaN
# 2 2022-10-05 06:26:28  92a2d8fd7144074f659d1d29dc3751da
# 3 2022-10-05 06:27:28  d60aa38f62b4977426b70944af4aff72
# 4 2022-10-05 06:27:44  cd6979b0b5265f08468fa1689b6300ce
#
#                  id_group_anonymous                                 media  \
# 0  12283e08a2eb5789201e105b34489ee7                                   NaN
# 1  12283e08a2eb5789201e105b34489ee7                                   NaN
# 2  9f2d7394334eb224c061c9740b5748fc                                   NaN
# 3  c8f2de56550ed0bf85249608b7ead93d  94dca4cda503100ebfda7ce2bcc060eb.jpg
# 4  e56ec342fc599ebb4ed89655eb6f03aa  5ad5c8bbe9da93a37fecf3e5aa5b0637.jpg
#
#   media_type media_url  has_media  has_media_url  trava_zap  \
# 0        NaN       NaN      False          False      False
# 1        NaN       NaN      False          False      False
# 2        NaN       NaN      False          False      False
# 3  image/jpg       NaN       True          False      False
# 4  image/jpg       NaN       True          False      False
#
#                               text_content_anonymous  dataset_info_id  \
# 0  Então é Fato Renato o áudio que eu ouvi no wha...                5
# 1  Saiu no YouTube do presidente a 8 horas atrás,...                5
# 2  É isso, nossa parte já foi quase toda feita. N...                5
# 3           GENTE ACHEI ELES EM UMA SEITA MAÇONÁRICA                5
# 4                                                NaN                5
#
#                  date_system  score_sentiment  score_misinformation  \
# 0 2022-10-05 06:25:28.863641           0.0000                   NaN
# 1 2022-10-05 06:25:28.926311           0.0644                   NaN
# 2 2022-10-05 06:26:29.361949          -0.3551              0.157242
# 3 2022-10-05 06:27:29.935624           0.0000                   NaN
# 4 2022-10-05 06:28:29.316325              NaN                   NaN
#
#    id_message message_type messenger media_name  \
# 0       16385        Texto  telegram        NaN
# 1       16386        Texto  telegram        NaN
# 2       16366        Texto  telegram        NaN
# 3       19281       Imagem  telegram        NaN
# 4      507185       Imagem  telegram        NaN
#
#                           media_md5
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3  94dca4cda503100ebfda7ce2bcc060eb
# 4  5ad5c8bbe9da93a37fecf3e5aa5b0637

# %%
# Contando a quantidade de caracteres da coluna texto
df['caracteres'] = df['text_content_anonymous'].str.len()
df[['text_content_anonymous', 'caracteres']]
# Out:
#                                    text_content_anonymous  caracteres
# 0       Então é Fato Renato o áudio que eu ouvi no wha...       110.0
# 1       Saiu no YouTube do presidente a 8 horas atrás,...       141.0
# 2       É isso, nossa parte já foi quase toda feita. N...       350.0
# 3                GENTE ACHEI ELES EM UMA SEITA MAÇONÁRICA        40.0
# 4                                                     NaN         NaN
# ...                                                   ...         ...
# 557581  BNDES tem lucro de R$ 9,6 bilhões no terceiro ...       152.0
# 557582                       https://youtu.be/8g1Vz9_0xVk        28.0
# 557583  Empresários, demitam os petistas primeiro.\n\n...        68.0
# 557584  Empresários, demitam os petistas primeiro.\n\n...        68.0
# 557585  Empresários, demitam os petistas primeiro.\n\n...        68.0
#
# [557586 rows x 2 columns]

# %%
sns.boxplot(df['caracteres'])
# Out:
# <AxesSubplot: >

# %%
sns.histplot(df['caracteres'], bins=50, kde=False)
# Out:
# c:\Users\ACER\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <AxesSubplot: xlabel='caracteres', ylabel='Count'>

# %% [markdown]
# ## Remoção de outliers

# %%
media = df['caracteres'].mean()
desvio = df['caracteres'].std()

limite_inferior = media - 3 * desvio
limite_superior = media + 3 * desvio


df_sem_outlier = df[(df['caracteres'] >= limite_inferior) & (df['caracteres'] <= limite_superior)]

df_sem_outlier.shape
# Out:
# (435054, 20)

# %%
sns.boxplot(df_sem_outlier['caracteres'])
# Out:
# <AxesSubplot: >

# %%
sns.histplot(df_sem_outlier['caracteres'], bins=50, kde=False)
# Out:
# c:\Users\ACER\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <AxesSubplot: xlabel='caracteres', ylabel='Count'>

# %%
df_sem_outlier['caracteres'].describe()
# Out:
# count    435054.000000
# mean        167.813651
# std         194.668772
# min           1.000000
# 25%          60.000000
# 50%          99.000000
# 75%         198.000000
# max        1437.000000
# Name: caracteres, dtype: float64

# %%
df['words'] = df['text_content_anonymous'].str.split().str.len()
df[['text_content_anonymous', 'words']]
# Out:
#                                    text_content_anonymous  words
# 0       Então é Fato Renato o áudio que eu ouvi no wha...   20.0
# 1       Saiu no YouTube do presidente a 8 horas atrás,...   23.0
# 2       É isso, nossa parte já foi quase toda feita. N...   59.0
# 3                GENTE ACHEI ELES EM UMA SEITA MAÇONÁRICA    7.0
# 4                                                     NaN    NaN
# ...                                                   ...    ...
# 557581  BNDES tem lucro de R$ 9,6 bilhões no terceiro ...   12.0
# 557582                       https://youtu.be/8g1Vz9_0xVk    1.0
# 557583  Empresários, demitam os petistas primeiro.\n\n...    6.0
# 557584  Empresários, demitam os petistas primeiro.\n\n...    6.0
# 557585  Empresários, demitam os petistas primeiro.\n\n...    6.0
#
# [557586 rows x 2 columns]

# %%
sns.histplot(df['words'], bins=50, kde=False)
# Out:
# c:\Users\ACER\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <AxesSubplot: xlabel='words', ylabel='Count'>

# %%
df['words'].describe()
# Out:
# count    444201.000000
# mean         32.474380
# std          66.960835
# min           1.000000
# 25%           6.000000
# 50%          15.000000
# 75%          30.000000
# max        1261.000000
# Name: words, dtype: float64

# %%
df['sharings'] = df['text_content_anonymous'].map(df['text_content_anonymous'].value_counts())

# %%
df['sharings']
# Out:
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         NaN
#          ...
# 557581    2.0
# 557582    2.0
# 557583    4.0
# 557584    4.0
# 557585    4.0
# Name: sharings, Length: 557586, dtype: float64

# %%
df['sharings'].describe()
# Out:
# count    444201.000000
# mean        708.840086
# std        3378.882834
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           6.000000
# max       17422.000000
# Name: sharings, dtype: float64

# %%
df['viral'] = np.where(df['sharings'] >=5, 1, 0)
df['viral']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 557581    0
# 557582    0
# 557583    0
# 557584    0
# 557585    0
# Name: viral, Length: 557586, dtype: int32

# %%
df['viral'].value_counts()
# Out:
# viral
# 0    424968
# 1    132618
# Name: count, dtype: int64

# %%
filtro_viral = df['viral'] == 1
df_so_viral = df[filtro_viral]
sns.histplot(df_so_viral['sharings'], bins=50, kde=False)
# Out:
# c:\Users\ACER\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <AxesSubplot: xlabel='sharings', ylabel='Count'>

# %%
df['sentiment'] = np.where(df['score_sentiment'] == 0, 'Neutro',
                           np.where(df['score_sentiment'] > 0.05, 'Positivo', 'Negativo'))

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# Negativo    244134
# Neutro      179968
# Positivo    133484
# Name: count, dtype: int64

# %%
df['trava_zap'].value_counts()
# Out:
# trava_zap
# False    557570
# True         16
# Name: count, dtype: int64

# %%
df_trava_zap_true = df[df['trava_zap'] == True]
df_trava_zap_true.head()
# Out:
#                date_message               id_member_anonymous  \
# 21944   2022-10-07 07:46:52                               NaN
# 89109   2022-10-16 00:45:02  8a30ac374bc4b5930eaf0667a178546a
# 294541  2022-10-04 14:22:47  39ee10516124280a22f1798f2a41f9a7
# 324567  2022-10-25 14:55:55  e003fbb6ffedb1838e42360d41cab314
# 389164  2022-10-30 20:19:52                               NaN
#
#                       id_group_anonymous media media_type media_url  \
# 21944   c712c1b704c22bd0cef50bc06125cdbd   NaN        NaN       NaN
# 89109   e56ec342fc599ebb4ed89655eb6f03aa   NaN        NaN       NaN
# 294541  959f13e0079883060632c74ffc81c547   NaN        NaN       NaN
# 324567  5b10d7739171149be6d9961e3350c071   NaN        NaN       NaN
# 389164  c8f2de56550ed0bf85249608b7ead93d   NaN        NaN       NaN
#
#         has_media  has_media_url  trava_zap text_content_anonymous  \
# 21944       False          False       True                    NaN
# 89109       False          False       True                    NaN
# 294541      False          False       True                    NaN
# 324567      False          False       True                    NaN
# 389164      False          False       True                    NaN
#
#         dataset_info_id                 date_system  score_sentiment  \
# 21944                 5  2022-10-07 07:47:00.355052           0.0000
# 89109                 5  2022-10-16 00:45:04.064662           0.0000
# 294541                5  2022-10-04 14:22:48.808572           0.9734
# 324567                5  2022-10-25 14:56:11.604972           0.9460
# 389164                5  2022-10-30 20:19:54.183578           0.0000
#
#         score_misinformation  id_message message_type messenger media_name  \
# 21944               0.067344       53260        Texto  telegram        NaN
# 89109               0.056698      521324        Texto  telegram        NaN
# 294541              0.010433       27241        Texto  telegram        NaN
# 324567              0.403945     1182938        Texto  telegram        NaN
# 389164                   NaN       28330        Texto  telegram        NaN
#
#        media_md5 sentiment
# 21944        NaN    Neutro
# 89109        NaN    Neutro
# 294541       NaN  Positivo
# 324567       NaN  Positivo
# 389164       NaN    Neutro

# %%
df['text_content_anonymous']
# Out:
# 0         Então é Fato Renato o áudio que eu ouvi no wha...
# 1         Saiu no YouTube do presidente a 8 horas atrás,...
# 2         É isso, nossa parte já foi quase toda feita. N...
# 3                  GENTE ACHEI ELES EM UMA SEITA MAÇONÁRICA
# 4                                                       NaN
#                                 ...
# 557581    BNDES tem lucro de R$ 9,6 bilhões no terceiro ...
# 557582                         https://youtu.be/8g1Vz9_0xVk
# 557583    Empresários, demitam os petistas primeiro.\n\n...
# 557584    Empresários, demitam os petistas primeiro.\n\n...
# 557585    Empresários, demitam os petistas primeiro.\n\n...
# Name: text_content_anonymous, Length: 557586, dtype: object

# %%
df_trava_zap = df.copy()

# %%
import re

df_trava_zap['text_content_anonymous'] = df_trava_zap['text_content_anonymous'].astype("string")
df_trava_zap['caracteres_especial_count'] = df_trava_zap['text_content_anonymous'].apply(
    lambda x: len(re.findall(r'[^A-Za-z0-9]', str(x))) if pd.notnull(x) else 0
)

# %%
df_trava_zap[['text_content_anonymous', 'caracteres_especial_count']]
# Out:
#                                    text_content_anonymous  \
# 0       Então é Fato Renato o áudio que eu ouvi no wha...
# 1       Saiu no YouTube do presidente a 8 horas atrás,...
# 2       É isso, nossa parte já foi quase toda feita. N...
# 3                GENTE ACHEI ELES EM UMA SEITA MAÇONÁRICA
# 4                                                    <NA>
# ...                                                   ...
# 557581  BNDES tem lucro de R$ 9,6 bilhões no terceiro ...
# 557582                       https://youtu.be/8g1Vz9_0xVk
# 557583  Empresários, demitam os petistas primeiro.
#
# ht...
# 557584  Empresários, demitam os petistas primeiro.
#
# ht...
# 557585  Empresários, demitam os petistas primeiro.
#
# ht...
#
#         caracteres_especial_count
# 0                              24
# 1                              29
# 2                              77
# 3                               8
# 4                               0
# ...                           ...
# 557581                         32
# 557582                          6
# 557583                         14
# 557584                         14
# 557585                         14
#
# [557586 rows x 2 columns]

# %%
sns.boxplot(df_trava_zap['caracteres_especial_count'])
# Out:
# <AxesSubplot: >

# %%
df_trava_zap['caracteres_especial_count'].describe()
# Out:
# count    557586.000000
# mean         42.428605
# std         101.838961
# min           0.000000
# 25%           5.000000
# 50%          17.000000
# 75%          38.000000
# max        4092.000000
# Name: caracteres_especial_count, dtype: float64

# %%
df_ordenado = df_trava_zap.sort_values(by='caracteres_especial_count', ascending=False)
df_ordenado
# Out:
#                date_message               id_member_anonymous  \
# 399869  2022-11-01 06:39:29                               NaN
# 399859  2022-11-01 06:39:24                               NaN
# 399870  2022-11-01 06:39:29                               NaN
# 399858  2022-11-01 06:39:24                               NaN
# 399860  2022-11-01 06:39:24                               NaN
# ...                     ...                               ...
# 126708  2022-10-17 17:36:20                               NaN
# 381339  2022-10-31 13:13:03                               NaN
# 286935  2022-10-03 19:34:17                               NaN
# 286937  2022-10-03 19:34:34  d36c39da7c9705400e5056e033363b65
# 172066  2022-10-08 17:17:00  8d1a3c5b2ba0f29df8a6a5be0bb66191
#
#                       id_group_anonymous  \
# 399869  d9c080b9db8cd9d0e88e870ce782c01a
# 399859  d9c080b9db8cd9d0e88e870ce782c01a
# 399870  d9c080b9db8cd9d0e88e870ce782c01a
# 399858  d9c080b9db8cd9d0e88e870ce782c01a
# 399860  d9c080b9db8cd9d0e88e870ce782c01a
# ...                                  ...
# 126708  9c2feb6ffd68ffe90b9dd60a8e4e4cba
# 381339  857cd5311da1bdc15eb9e6918a47c6c6
# 286935  ed3a8a78a8ecceab27b0a5be875a8c1b
# 286937  86bd52718a6a22ac8fea566dc38d2026
# 172066  857cd5311da1bdc15eb9e6918a47c6c6
#
#                                        media media_type media_url  has_media  \
# 399869                                   NaN        NaN       NaN      False
# 399859                                   NaN        NaN       NaN      False
# 399870                                   NaN        NaN       NaN      False
# 399858                                   NaN        NaN       NaN      False
# 399860                                   NaN        NaN       NaN      False
# ...                                      ...        ...       ...        ...
# 126708  0b3c401b00cf696ac0b2c482261b3c2e.jpg  image/jpg       NaN       True
# 381339  f97dc502d2c21790e54d7990eafca89a.jpg  image/jpg       NaN       True
# 286935  7f8b5f52f09821f26355b331c15fc82a.jpg  image/jpg       NaN       True
# 286937  9a2252e588e6e25cd99ed10836477e8d.jpg  image/jpg       NaN       True
# 172066  2a57b00ee239e190b7999025eb926de8.jpg  image/jpg       NaN       True
#
#         has_media_url  trava_zap  \
# 399869          False      False
# 399859          False      False
# 399870          False      False
# 399858          False      False
# 399860          False      False
# ...               ...        ...
# 126708          False      False
# 381339          False      False
# 286935          False      False
# 286937          False      False
# 172066          False      False
#
#                                    text_content_anonymous  ...  \
# 399869  *๘๘๘๘๘๘๘๘* *๕๕๕๕๕๕๕๕* *๘๘๘๘๘๘๘๘* *๘๘๘๘๘๘๘๘* *๕...  ...
# 399859  *๘๘๘๘๘๘๘๘* *๕๕๕๕๕๕๕๕* *๘๘๘๘๘๘๘๘* *๘๘๘๘๘๘๘๘* *๕...  ...
# 399870  *๘๘๘๘๘๘๘๘* *๕๕๕๕๕๕๕๕* *๘๘๘๘๘๘๘๘* *๘๘๘๘๘๘๘๘* *๕...  ...
# 399858  *๘๘๘๘๘๘๘๘* *๕๕๕๕๕๕๕๕* *๘๘๘๘๘๘๘๘* *๘๘๘๘๘๘๘๘* *๕...  ...
# 399860  *๘๘๘๘๘๘๘๘* *๕๕๕๕๕๕๕๕* *๘๘๘๘๘๘๘๘*
#
# *๘๘๘๘๘๘๘๘* *...  ...
# ...                                                   ...  ...
# 126708                                               <NA>  ...
# 381339                                               <NA>  ...
# 286935                                               <NA>  ...
# 286937                                               <NA>  ...
# 172066                                               <NA>  ...
#
#                        date_system score_sentiment  score_misinformation  \
# 399869  2022-11-01 06:40:27.724734             0.0                   NaN
# 399859  2022-11-01 06:39:46.326797             0.0                   NaN
# 399870  2022-11-01 06:40:27.823781             0.0                   NaN
# 399858  2022-11-01 06:39:46.244728             0.0                   NaN
# 399860  2022-11-01 06:39:46.419768             0.0                   NaN
# ...                            ...             ...                   ...
# 126708  2022-10-17 17:36:21.600388             NaN                   NaN
# 381339  2022-10-31 13:13:21.785435             NaN                   NaN
# 286935  2022-10-03 19:34:18.266913             NaN                   NaN
# 286937    2022-10-03 19:34:35.6388             NaN                   NaN
# 172066   2022-10-08 17:17:25.81686             NaN                   NaN
#
#         id_message  message_type messenger media_name  \
# 399869      328974         Texto  telegram        NaN
# 399859      328957         Texto  telegram        NaN
# 399870      328973         Texto  telegram        NaN
# 399858      328956         Texto  telegram        NaN
# 399860      328958         Texto  telegram        NaN
# ...            ...           ...       ...        ...
# 126708        5966        Imagem  telegram        NaN
# 381339      981623        Imagem  telegram        NaN
# 286935         838        Imagem  telegram        NaN
# 286937        3892        Imagem  telegram        NaN
# 172066      901838        Imagem  telegram        NaN
#
#                                media_md5 sentiment caracteres_especial_count
# 399869                               NaN    Neutro                      4092
# 399859                               NaN    Neutro                      4092
# 399870                               NaN    Neutro                      4091
# 399858                               NaN    Neutro                      4091
# 399860                               NaN    Neutro                      4085
# ...                                  ...       ...                       ...
# 126708  0b3c401b00cf696ac0b2c482261b3c2e  Negativo                         0
# 381339  f97dc502d2c21790e54d7990eafca89a  Negativo                         0
# 286935  7f8b5f52f09821f26355b331c15fc82a  Negativo                         0
# 286937  9a2252e588e6e25cd99ed10836477e8d  Negativo                         0
# 172066  2a57b00ee239e190b7999025eb926de8  Negativo                         0
#
# [557586 rows x 21 columns]

# %%
df_ordenado['caracteres_especial_count'].value_counts()
# Out:
# caracteres_especial_count
# 0       113900
# 17       35175
# 5        33788
# 6        13723
# 16       10994
#          ...
# 1139         1
# 1140         1
# 1150         1
# 1152         1
# 1206         1
# Name: count, Length: 1201, dtype: int64

# %%
num_caracteres_elevado = df_ordenado['caracteres_especial_count'] >= 1900
df_caracteres_elevado = df_ordenado[num_caracteres_elevado]
df_caracteres_elevado.head()
# Out:
#                date_message id_member_anonymous  \
# 399869  2022-11-01 06:39:29                 NaN
# 399859  2022-11-01 06:39:24                 NaN
# 399870  2022-11-01 06:39:29                 NaN
# 399858  2022-11-01 06:39:24                 NaN
# 399860  2022-11-01 06:39:24                 NaN
#
#                       id_group_anonymous media media_type media_url  \
# 399869  d9c080b9db8cd9d0e88e870ce782c01a   NaN        NaN       NaN
# 399859  d9c080b9db8cd9d0e88e870ce782c01a   NaN        NaN       NaN
# 399870  d9c080b9db8cd9d0e88e870ce782c01a   NaN        NaN       NaN
# 399858  d9c080b9db8cd9d0e88e870ce782c01a   NaN        NaN       NaN
# 399860  d9c080b9db8cd9d0e88e870ce782c01a   NaN        NaN       NaN
#
#         has_media  has_media_url  trava_zap  \
# 399869      False          False      False
# 399859      False          False      False
# 399870      False          False      False
# 399858      False          False      False
# 399860      False          False      False
#
#                                    text_content_anonymous  ...  \
# 399869  *๘๘๘๘๘๘๘๘* *๕๕๕๕๕๕๕๕* *๘๘๘๘๘๘๘๘* *๘๘๘๘๘๘๘๘* *๕...  ...
# 399859  *๘๘๘๘๘๘๘๘* *๕๕๕๕๕๕๕๕* *๘๘๘๘๘๘๘๘* *๘๘๘๘๘๘๘๘* *๕...  ...
# 399870  *๘๘๘๘๘๘๘๘* *๕๕๕๕๕๕๕๕* *๘๘๘๘๘๘๘๘* *๘๘๘๘๘๘๘๘* *๕...  ...
# 399858  *๘๘๘๘๘๘๘๘* *๕๕๕๕๕๕๕๕* *๘๘๘๘๘๘๘๘* *๘๘๘๘๘๘๘๘* *๕...  ...
# 399860  *๘๘๘๘๘๘๘๘* *๕๕๕๕๕๕๕๕* *๘๘๘๘๘๘๘๘*
#
# *๘๘๘๘๘๘๘๘* *...  ...
#
#                        date_system score_sentiment  score_misinformation  \
# 399869  2022-11-01 06:40:27.724734             0.0                   NaN
# 399859  2022-11-01 06:39:46.326797             0.0                   NaN
# 399870  2022-11-01 06:40:27.823781             0.0                   NaN
# 399858  2022-11-01 06:39:46.244728             0.0                   NaN
# 399860  2022-11-01 06:39:46.419768             0.0                   NaN
#
#         id_message  message_type messenger media_name media_md5 sentiment  \
# 399869      328974         Texto  telegram        NaN       NaN    Neutro
# 399859      328957         Texto  telegram        NaN       NaN    Neutro
# 399870      328973         Texto  telegram        NaN       NaN    Neutro
# 399858      328956         Texto  telegram        NaN       NaN    Neutro
# 399860      328958         Texto  telegram        NaN       NaN    Neutro
#
#        caracteres_especial_count
# 399869                      4092
# 399859                      4092
# 399870                      4091
# 399858                      4091
# 399860                      4085
#
# [5 rows x 21 columns]

# %%
df_caracteres_elevado.shape
# Out:
# (55, 21)

# %%
# eliminando trava_zap

df['text_content_anonymous'] = df['text_content_anonymous'].astype("string")
df['caracteres_especial_count'] = df['text_content_anonymous'].apply(
    lambda x: len(re.findall(r'[^A-Za-z0-9]', str(x))) if pd.notnull(x) else 0
)

num_caracteres_elevado = df['caracteres_especial_count'] >= 1900
df_final = df[~num_caracteres_elevado]
df_final.head()
# Out:
#           date_message               id_member_anonymous  \
# 0  2022-10-05 06:25:04  1078cc958f0febe28f4d03207660715f
# 1  2022-10-05 06:25:08                               NaN
# 2  2022-10-05 06:26:28  92a2d8fd7144074f659d1d29dc3751da
# 3  2022-10-05 06:27:28  d60aa38f62b4977426b70944af4aff72
# 4  2022-10-05 06:27:44  cd6979b0b5265f08468fa1689b6300ce
#
#                  id_group_anonymous                                 media  \
# 0  12283e08a2eb5789201e105b34489ee7                                   NaN
# 1  12283e08a2eb5789201e105b34489ee7                                   NaN
# 2  9f2d7394334eb224c061c9740b5748fc                                   NaN
# 3  c8f2de56550ed0bf85249608b7ead93d  94dca4cda503100ebfda7ce2bcc060eb.jpg
# 4  e56ec342fc599ebb4ed89655eb6f03aa  5ad5c8bbe9da93a37fecf3e5aa5b0637.jpg
#
#   media_type media_url  has_media  has_media_url  trava_zap  \
# 0        NaN       NaN      False          False      False
# 1        NaN       NaN      False          False      False
# 2        NaN       NaN      False          False      False
# 3  image/jpg       NaN       True          False      False
# 4  image/jpg       NaN       True          False      False
#
#                               text_content_anonymous  ...  \
# 0  Então é Fato Renato o áudio que eu ouvi no wha...  ...
# 1  Saiu no YouTube do presidente a 8 horas atrás,...  ...
# 2  É isso, nossa parte já foi quase toda feita. N...  ...
# 3           GENTE ACHEI ELES EM UMA SEITA MAÇONÁRICA  ...
# 4                                               <NA>  ...
#
#                   date_system score_sentiment  score_misinformation  \
# 0  2022-10-05 06:25:28.863641          0.0000                   NaN
# 1  2022-10-05 06:25:28.926311          0.0644                   NaN
# 2  2022-10-05 06:26:29.361949         -0.3551              0.157242
# 3  2022-10-05 06:27:29.935624          0.0000                   NaN
# 4  2022-10-05 06:28:29.316325             NaN                   NaN
#
#    id_message  message_type messenger media_name  \
# 0       16385         Texto  telegram        NaN
# 1       16386         Texto  telegram        NaN
# 2       16366         Texto  telegram        NaN
# 3       19281        Imagem  telegram        NaN
# 4      507185        Imagem  telegram        NaN
#
#                           media_md5 sentiment caracteres_especial_count
# 0                               NaN    Neutro                        24
# 1                               NaN  Positivo                        29
# 2                               NaN  Negativo                        77
# 3  94dca4cda503100ebfda7ce2bcc060eb    Neutro                         8
# 4  5ad5c8bbe9da93a37fecf3e5aa5b0637  Negativo                         0
#
# [5 rows x 21 columns]

# %%
df_final.shape
# Out:
# (557531, 21)
